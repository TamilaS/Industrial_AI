# %%
# !pip install deep-daze --upgrade

# %%
# !pip install Pillow==9.0.0
# Out:
# Collecting Pillow==9.0.0
#   Downloading Pillow-9.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 12.5 MB/s
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.1.0
#     Uninstalling Pillow-9.1.0:
#       Successfully uninstalled Pillow-9.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-9.0.0

# %%
from tqdm.notebook import trange
from IPython.display import Image, display

from deep_daze import Imagine

TEXT = 'storks otters wolves' #@param {type:"string"}
NUM_LAYERS = 32 #@param {type:"number"}
SAVE_EVERY =  20#@param {type:"number"}
IMAGE_WIDTH = 512 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 1e-5 #@param {type:"number"}
ITERATIONS = 100 #@param {type:"number"}

model = Imagine(
    text = TEXT,
    num_layers = NUM_LAYERS,
    save_every = SAVE_EVERY,
    image_width = IMAGE_WIDTH,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(ITERATIONS, desc = 'iteration'):
        model.train_step(epoch, i)

        if i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./{filename}.jpg')
        display(image)
# Out:
# Setting jit to False because torch version is not 1.7.1.
# Downloading ViT-B-32.pt: 100%|██████████| 354M/354M [00:12<00:00, 27.9MiB/s]
# epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
# image updated at "./storks_otters_wolves.jpg"
# image updated at "./storks_otters_wolves.000001.jpg"
# image updated at "./storks_otters_wolves.000002.jpg"
# image updated at "./storks_otters_wolves.000003.jpg"
# image updated at "./storks_otters_wolves.000004.jpg"
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
# image updated at "./storks_otters_wolves.000005.jpg"
# image updated at "./storks_otters_wolves.000006.jpg"
# image updated at "./storks_otters_wolves.000007.jpg"
# image updated at "./storks_otters_wolves.000008.jpg"
# image updated at "./storks_otters_wolves.000009.jpg"
# iteration:   0%|          | 0/100 [00:00<?, ?it/s]
# image updated at "./storks_otters_wolves.000010.jpg"
# image updated at "./storks_otters_wolves.000011.jpg"
